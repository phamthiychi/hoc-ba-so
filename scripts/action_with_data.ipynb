# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager
from src.adapter.database.mongo_manager import mongo_manager
from src.adapter.graph.neo4j_manager import neo4j_manager

postgres_manager.delete_db()
postgres_manager.create_db()

mongo_manager.clean_metadata_db("contact_infos")
mongo_manager.clean_metadata_db("subject_assessments")

neo4j_manager.clean_database()
# Out:
# 2026-04-03 23:24:54,717 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-04-03 23:24:54,722 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-03 23:24:55,009 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-04-03 23:24:55,014 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-03 23:24:55,301 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-04-03 23:24:55,304 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-03 23:24:55,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-03 23:24:55,609 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:55,611 INFO sqlalchemy.engine.Engine [generated in 0.00236s] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:55,898 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:55,903 INFO sqlalchemy.engine.Engine [cached since 0.2946s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,050 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,052 INFO sqlalchemy.engine.Engine [cached since 0.4435s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,196 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,198 INFO sqlalchemy.engine.Engine [cached since 0.5895s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,346 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,347 INFO sqlalchemy.engine.Engine [cached since 0.7388s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,489 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,490 INFO sqlalchemy.engine.Engine [cached since 0.8822s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,634 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,635 INFO sqlalchemy.engine.Engine [cached since 1.027s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,777 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,778 INFO sqlalchemy.engine.Engine [cached since 1.17s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:56,919 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:56,920 INFO sqlalchemy.engine.Engine [cached since 1.312s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:57,061 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:57,063 INFO sqlalchemy.engine.Engine [cached since 1.455s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:57,205 INFO sqlalchemy.engine.Engine
# DROP TABLE teaching_assignment
# 2026-04-03 23:24:57,206 INFO sqlalchemy.engine.Engine [no key 0.00103s] {}
# 2026-04-03 23:24:57,362 INFO sqlalchemy.engine.Engine
# DROP TABLE learning_result
# 2026-04-03 23:24:57,364 INFO sqlalchemy.engine.Engine [no key 0.00158s] {}
# 2026-04-03 23:24:57,509 INFO sqlalchemy.engine.Engine
# DROP TABLE class_room
# 2026-04-03 23:24:57,511 INFO sqlalchemy.engine.Engine [no key 0.00291s] {}
# 2026-04-03 23:24:57,655 INFO sqlalchemy.engine.Engine
# DROP TABLE teacher
# 2026-04-03 23:24:57,657 INFO sqlalchemy.engine.Engine [no key 0.00181s] {}
# 2026-04-03 23:24:57,800 INFO sqlalchemy.engine.Engine
# DROP TABLE subject
# 2026-04-03 23:24:57,802 INFO sqlalchemy.engine.Engine [no key 0.00258s] {}
# 2026-04-03 23:24:57,946 INFO sqlalchemy.engine.Engine
# DROP TABLE student
# 2026-04-03 23:24:57,948 INFO sqlalchemy.engine.Engine [no key 0.00196s] {}
# 2026-04-03 23:24:58,093 INFO sqlalchemy.engine.Engine
# DROP TABLE semester
# 2026-04-03 23:24:58,096 INFO sqlalchemy.engine.Engine [no key 0.00305s] {}
# 2026-04-03 23:24:58,239 INFO sqlalchemy.engine.Engine
# DROP TABLE score
# 2026-04-03 23:24:58,242 INFO sqlalchemy.engine.Engine [no key 0.00288s] {}
# 2026-04-03 23:24:58,385 INFO sqlalchemy.engine.Engine
# DROP TABLE grade_level
# 2026-04-03 23:24:58,391 INFO sqlalchemy.engine.Engine [no key 0.00627s] {}
# 2026-04-03 23:24:58,538 INFO sqlalchemy.engine.Engine
# DROP TABLE academic_year
# 2026-04-03 23:24:58,540 INFO sqlalchemy.engine.Engine [no key 0.00242s] {}
# 2026-04-03 23:24:58,684 INFO sqlalchemy.engine.Engine COMMIT
# All tables dropped
# 2026-04-03 23:24:58,837 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-03 23:24:58,840 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:58,842 INFO sqlalchemy.engine.Engine [cached since 3.234s ago] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:59,126 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:59,129 INFO sqlalchemy.engine.Engine [cached since 3.52s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:59,273 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:59,275 INFO sqlalchemy.engine.Engine [cached since 3.667s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:59,419 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:59,423 INFO sqlalchemy.engine.Engine [cached since 3.815s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:59,568 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:59,573 INFO sqlalchemy.engine.Engine [cached since 3.965s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:59,717 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:59,718 INFO sqlalchemy.engine.Engine [cached since 4.11s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:24:59,860 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:24:59,862 INFO sqlalchemy.engine.Engine [cached since 4.253s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:25:00,004 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:25:00,007 INFO sqlalchemy.engine.Engine [cached since 4.398s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:25:00,152 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:25:00,155 INFO sqlalchemy.engine.Engine [cached since 4.547s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:25:00,298 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-03 23:25:00,302 INFO sqlalchemy.engine.Engine [cached since 4.694s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-03 23:25:00,447 INFO sqlalchemy.engine.Engine
# CREATE TABLE academic_year (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:00,453 INFO sqlalchemy.engine.Engine [no key 0.00604s] {}
# 2026-04-03 23:25:00,605 INFO sqlalchemy.engine.Engine
# CREATE TABLE grade_level (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	max_students INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:00,609 INFO sqlalchemy.engine.Engine [no key 0.00389s] {}
# 2026-04-03 23:25:00,756 INFO sqlalchemy.engine.Engine
# CREATE TABLE score (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:00,758 INFO sqlalchemy.engine.Engine [no key 0.00223s] {}
# 2026-04-03 23:25:00,902 INFO sqlalchemy.engine.Engine
# CREATE TABLE semester (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(20) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:00,903 INFO sqlalchemy.engine.Engine [no key 0.00087s] {}
# 2026-04-03 23:25:01,045 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	address TEXT,
# 	place_of_birth TEXT,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:01,045 INFO sqlalchemy.engine.Engine [no key 0.00074s] {}
# 2026-04-03 23:25:01,192 INFO sqlalchemy.engine.Engine
# CREATE TABLE subject (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	total_periods INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:01,194 INFO sqlalchemy.engine.Engine [no key 0.00226s] {}
# 2026-04-03 23:25:01,340 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	specialization VARCHAR(50),
# 	position VARCHAR(50),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-03 23:25:01,342 INFO sqlalchemy.engine.Engine [no key 0.00208s] {}
# 2026-04-03 23:25:01,483 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_room (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	size INTEGER NOT NULL,
# 	special_program VARCHAR(50),
# 	grade_level_code VARCHAR(20) NOT NULL,
# 	PRIMARY KEY (code),
# 	FOREIGN KEY(grade_level_code) REFERENCES grade_level (code)
# )
#
#
# 2026-04-03 23:25:01,483 INFO sqlalchemy.engine.Engine [no key 0.00347s] {}
# 2026-04-03 23:25:01,636 INFO sqlalchemy.engine.Engine
# CREATE TABLE learning_result (
# 	student_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	academic_year_code VARCHAR(20) NOT NULL,
# 	semester_code VARCHAR(20) NOT NULL,
# 	score_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	enrollment_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_code, class_code, academic_year_code, semester_code, score_code, subject_code),
# 	FOREIGN KEY(student_code) REFERENCES student (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_code) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_code) REFERENCES semester (code),
# 	FOREIGN KEY(score_code) REFERENCES score (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-03 23:25:01,638 INFO sqlalchemy.engine.Engine [no key 0.00138s] {}
# 2026-04-03 23:25:01,785 INFO sqlalchemy.engine.Engine
# CREATE TABLE teaching_assignment (
# 	teacher_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	role VARCHAR(30) NOT NULL,
# 	periods_per_week INTEGER NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (teacher_code, class_code, subject_code),
# 	FOREIGN KEY(teacher_code) REFERENCES teacher (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-03 23:25:01,787 INFO sqlalchemy.engine.Engine [no key 0.00207s] {}
# 2026-04-03 23:25:01,933 INFO sqlalchemy.engine.Engine COMMIT
# 2026-04-03 23:25:02,079 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-03 23:25:02,085 INFO sqlalchemy.engine.Engine ALTER TABLE academic_year ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:02,088 INFO sqlalchemy.engine.Engine [generated in 0.00856s] {}
# 2026-04-03 23:25:02,374 INFO sqlalchemy.engine.Engine ALTER TABLE learning_result ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:02,376 INFO sqlalchemy.engine.Engine [generated in 0.00242s] {}
# 2026-04-03 23:25:02,519 INFO sqlalchemy.engine.Engine ALTER TABLE class_room ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:02,521 INFO sqlalchemy.engine.Engine [generated in 0.00199s] {}
# 2026-04-03 23:25:02,662 INFO sqlalchemy.engine.Engine ALTER TABLE grade_level ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:02,665 INFO sqlalchemy.engine.Engine [generated in 0.00307s] {}
# 2026-04-03 23:25:02,810 INFO sqlalchemy.engine.Engine ALTER TABLE score ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:02,812 INFO sqlalchemy.engine.Engine [generated in 0.00142s] {}
# 2026-04-03 23:25:02,952 INFO sqlalchemy.engine.Engine ALTER TABLE semester ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:02,954 INFO sqlalchemy.engine.Engine [generated in 0.00154s] {}
# 2026-04-03 23:25:03,095 INFO sqlalchemy.engine.Engine ALTER TABLE student ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:03,096 INFO sqlalchemy.engine.Engine [generated in 0.00114s] {}
# 2026-04-03 23:25:03,239 INFO sqlalchemy.engine.Engine ALTER TABLE subject ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:03,242 INFO sqlalchemy.engine.Engine [generated in 0.00300s] {}
# 2026-04-03 23:25:03,385 INFO sqlalchemy.engine.Engine ALTER TABLE teacher ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:03,387 INFO sqlalchemy.engine.Engine [generated in 0.00224s] {}
# 2026-04-03 23:25:03,531 INFO sqlalchemy.engine.Engine ALTER TABLE teaching_assignment ENABLE ROW LEVEL SECURITY;
# 2026-04-03 23:25:03,535 INFO sqlalchemy.engine.Engine [generated in 0.00409s] {}
# 2026-04-03 23:25:03,678 INFO sqlalchemy.engine.Engine COMMIT
# Tables created + RLS enabled
# Tables created
