# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager
from src.adapter.database.mongo_manager import mongo_manager
from src.adapter.graph.neo4j_manager import neo4j_manager

postgres_manager.delete_db()
postgres_manager.create_db()

mongo_manager.clean_metadata_db("contact_infos")
mongo_manager.clean_metadata_db("subject_assessments")

neo4j_manager.clean_database()
# Out:
# 2026-04-04 23:38:24,298 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-04-04 23:38:24,301 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-04 23:38:24,580 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-04-04 23:38:24,581 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-04 23:38:24,872 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-04-04 23:38:24,874 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-04 23:38:25,152 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-04 23:38:25,162 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:25,164 INFO sqlalchemy.engine.Engine [generated in 0.00172s] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:25,442 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:25,443 INFO sqlalchemy.engine.Engine [cached since 0.2814s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:25,588 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:25,592 INFO sqlalchemy.engine.Engine [cached since 0.4304s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:25,736 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:25,738 INFO sqlalchemy.engine.Engine [cached since 0.5757s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:25,877 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:25,881 INFO sqlalchemy.engine.Engine [cached since 0.7185s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:26,021 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:26,024 INFO sqlalchemy.engine.Engine [cached since 0.8618s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:26,167 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:26,172 INFO sqlalchemy.engine.Engine [cached since 1.01s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:26,313 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:26,317 INFO sqlalchemy.engine.Engine [cached since 1.155s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:26,459 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:26,460 INFO sqlalchemy.engine.Engine [cached since 1.298s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:26,600 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:26,605 INFO sqlalchemy.engine.Engine [cached since 1.443s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:26,747 INFO sqlalchemy.engine.Engine
# DROP TABLE teaching_assignment
# 2026-04-04 23:38:26,753 INFO sqlalchemy.engine.Engine [no key 0.00627s] {}
# 2026-04-04 23:38:26,947 INFO sqlalchemy.engine.Engine
# DROP TABLE learning_result
# 2026-04-04 23:38:26,952 INFO sqlalchemy.engine.Engine [no key 0.00498s] {}
# 2026-04-04 23:38:27,097 INFO sqlalchemy.engine.Engine
# DROP TABLE class_room
# 2026-04-04 23:38:27,102 INFO sqlalchemy.engine.Engine [no key 0.00433s] {}
# 2026-04-04 23:38:27,241 INFO sqlalchemy.engine.Engine
# DROP TABLE teacher
# 2026-04-04 23:38:27,243 INFO sqlalchemy.engine.Engine [no key 0.00156s] {}
# 2026-04-04 23:38:27,386 INFO sqlalchemy.engine.Engine
# DROP TABLE subject
# 2026-04-04 23:38:27,387 INFO sqlalchemy.engine.Engine [no key 0.00087s] {}
# 2026-04-04 23:38:27,527 INFO sqlalchemy.engine.Engine
# DROP TABLE student
# 2026-04-04 23:38:27,529 INFO sqlalchemy.engine.Engine [no key 0.00139s] {}
# 2026-04-04 23:38:27,669 INFO sqlalchemy.engine.Engine
# DROP TABLE semester
# 2026-04-04 23:38:27,671 INFO sqlalchemy.engine.Engine [no key 0.00210s] {}
# 2026-04-04 23:38:27,811 INFO sqlalchemy.engine.Engine
# DROP TABLE score
# 2026-04-04 23:38:27,819 INFO sqlalchemy.engine.Engine [no key 0.00691s] {}
# 2026-04-04 23:38:27,960 INFO sqlalchemy.engine.Engine
# DROP TABLE grade_level
# 2026-04-04 23:38:27,964 INFO sqlalchemy.engine.Engine [no key 0.00352s] {}
# 2026-04-04 23:38:28,108 INFO sqlalchemy.engine.Engine
# DROP TABLE academic_year
# 2026-04-04 23:38:28,112 INFO sqlalchemy.engine.Engine [no key 0.00397s] {}
# 2026-04-04 23:38:28,256 INFO sqlalchemy.engine.Engine COMMIT
# All tables dropped
# 2026-04-04 23:38:28,404 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-04 23:38:28,406 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:28,407 INFO sqlalchemy.engine.Engine [cached since 3.245s ago] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:28,685 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:28,687 INFO sqlalchemy.engine.Engine [cached since 3.525s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:28,830 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:28,835 INFO sqlalchemy.engine.Engine [cached since 3.673s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:28,975 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:28,978 INFO sqlalchemy.engine.Engine [cached since 3.816s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,121 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:29,122 INFO sqlalchemy.engine.Engine [cached since 3.961s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,261 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:29,264 INFO sqlalchemy.engine.Engine [cached since 4.103s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,405 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:29,407 INFO sqlalchemy.engine.Engine [cached since 4.246s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,549 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:29,552 INFO sqlalchemy.engine.Engine [cached since 4.391s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,692 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:29,694 INFO sqlalchemy.engine.Engine [cached since 4.532s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,834 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-04 23:38:29,836 INFO sqlalchemy.engine.Engine [cached since 4.674s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-04 23:38:29,976 INFO sqlalchemy.engine.Engine
# CREATE TABLE academic_year (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:29,978 INFO sqlalchemy.engine.Engine [no key 0.00174s] {}
# 2026-04-04 23:38:30,152 INFO sqlalchemy.engine.Engine
# CREATE TABLE grade_level (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	max_students INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:30,155 INFO sqlalchemy.engine.Engine [no key 0.00261s] {}
# 2026-04-04 23:38:30,300 INFO sqlalchemy.engine.Engine
# CREATE TABLE score (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:30,304 INFO sqlalchemy.engine.Engine [no key 0.00292s] {}
# 2026-04-04 23:38:30,446 INFO sqlalchemy.engine.Engine
# CREATE TABLE semester (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(20) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:30,452 INFO sqlalchemy.engine.Engine [no key 0.00520s] {}
# 2026-04-04 23:38:30,595 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	address TEXT,
# 	place_of_birth TEXT,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:30,596 INFO sqlalchemy.engine.Engine [no key 0.00121s] {}
# 2026-04-04 23:38:30,746 INFO sqlalchemy.engine.Engine
# CREATE TABLE subject (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	total_periods INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:30,748 INFO sqlalchemy.engine.Engine [no key 0.00235s] {}
# 2026-04-04 23:38:30,891 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	specialization VARCHAR(50),
# 	position VARCHAR(50),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-04 23:38:30,893 INFO sqlalchemy.engine.Engine [no key 0.00191s] {}
# 2026-04-04 23:38:31,035 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_room (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	size INTEGER NOT NULL,
# 	special_program VARCHAR(50),
# 	grade_level_code VARCHAR(20) NOT NULL,
# 	PRIMARY KEY (code),
# 	FOREIGN KEY(grade_level_code) REFERENCES grade_level (code)
# )
#
#
# 2026-04-04 23:38:31,037 INFO sqlalchemy.engine.Engine [no key 0.00204s] {}
# 2026-04-04 23:38:31,187 INFO sqlalchemy.engine.Engine
# CREATE TABLE learning_result (
# 	student_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	academic_year_code VARCHAR(20) NOT NULL,
# 	semester_code VARCHAR(20) NOT NULL,
# 	score_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	enrollment_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_code, class_code, academic_year_code, semester_code, score_code, subject_code),
# 	FOREIGN KEY(student_code) REFERENCES student (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_code) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_code) REFERENCES semester (code),
# 	FOREIGN KEY(score_code) REFERENCES score (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-04 23:38:31,190 INFO sqlalchemy.engine.Engine [no key 0.00337s] {}
# 2026-04-04 23:38:31,340 INFO sqlalchemy.engine.Engine
# CREATE TABLE teaching_assignment (
# 	teacher_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	role VARCHAR(30) NOT NULL,
# 	periods_per_week INTEGER NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (teacher_code, class_code, subject_code),
# 	FOREIGN KEY(teacher_code) REFERENCES teacher (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-04 23:38:31,344 INFO sqlalchemy.engine.Engine [no key 0.00419s] {}
# 2026-04-04 23:38:31,493 INFO sqlalchemy.engine.Engine COMMIT
# 2026-04-04 23:38:31,634 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-04 23:38:31,635 INFO sqlalchemy.engine.Engine ALTER TABLE academic_year ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:31,637 INFO sqlalchemy.engine.Engine [generated in 0.00326s] {}
# 2026-04-04 23:38:31,911 INFO sqlalchemy.engine.Engine ALTER TABLE learning_result ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:31,917 INFO sqlalchemy.engine.Engine [generated in 0.00602s] {}
# 2026-04-04 23:38:32,059 INFO sqlalchemy.engine.Engine ALTER TABLE class_room ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,061 INFO sqlalchemy.engine.Engine [generated in 0.00223s] {}
# 2026-04-04 23:38:32,203 INFO sqlalchemy.engine.Engine ALTER TABLE grade_level ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,205 INFO sqlalchemy.engine.Engine [generated in 0.00192s] {}
# 2026-04-04 23:38:32,346 INFO sqlalchemy.engine.Engine ALTER TABLE score ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,348 INFO sqlalchemy.engine.Engine [generated in 0.00198s] {}
# 2026-04-04 23:38:32,490 INFO sqlalchemy.engine.Engine ALTER TABLE semester ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,492 INFO sqlalchemy.engine.Engine [generated in 0.00170s] {}
# 2026-04-04 23:38:32,632 INFO sqlalchemy.engine.Engine ALTER TABLE student ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,635 INFO sqlalchemy.engine.Engine [generated in 0.00281s] {}
# 2026-04-04 23:38:32,774 INFO sqlalchemy.engine.Engine ALTER TABLE subject ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,776 INFO sqlalchemy.engine.Engine [generated in 0.00270s] {}
# 2026-04-04 23:38:32,917 INFO sqlalchemy.engine.Engine ALTER TABLE teacher ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:32,918 INFO sqlalchemy.engine.Engine [generated in 0.00187s] {}
# 2026-04-04 23:38:33,063 INFO sqlalchemy.engine.Engine ALTER TABLE teaching_assignment ENABLE ROW LEVEL SECURITY;
# 2026-04-04 23:38:33,067 INFO sqlalchemy.engine.Engine [generated in 0.00395s] {}
# 2026-04-04 23:38:33,205 INFO sqlalchemy.engine.Engine COMMIT
# Tables created + RLS enabled
# Tables created
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
