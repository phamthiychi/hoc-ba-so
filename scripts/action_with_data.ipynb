# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager
from src.adapter.database.mongo_manager import mongo_manager
from src.adapter.graph.neo4j_manager import neo4j_manager

postgres_manager.delete_db()
postgres_manager.create_db()

mongo_manager.clean_metadata_db("contact_infos")
mongo_manager.clean_metadata_db("subject_assessments")

neo4j_manager.clean_database()
# Out:
# 2026-04-10 22:01:28,811 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-04-10 22:01:28,814 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-10 22:01:29,179 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-04-10 22:01:29,182 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-10 22:01:29,540 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-04-10 22:01:29,543 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-10 22:01:29,902 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 22:01:29,927 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:29,929 INFO sqlalchemy.engine.Engine [generated in 0.00142s] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:30,295 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:30,298 INFO sqlalchemy.engine.Engine [cached since 0.3709s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:30,489 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:30,492 INFO sqlalchemy.engine.Engine [cached since 0.565s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:30,678 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:30,682 INFO sqlalchemy.engine.Engine [cached since 0.7549s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:30,864 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:30,866 INFO sqlalchemy.engine.Engine [cached since 0.9393s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:31,061 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:31,064 INFO sqlalchemy.engine.Engine [cached since 1.137s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:31,246 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:31,249 INFO sqlalchemy.engine.Engine [cached since 1.322s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:31,434 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:31,442 INFO sqlalchemy.engine.Engine [cached since 1.515s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:31,627 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:31,630 INFO sqlalchemy.engine.Engine [cached since 1.703s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:31,810 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:31,814 INFO sqlalchemy.engine.Engine [cached since 1.888s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:32,001 INFO sqlalchemy.engine.Engine
# DROP TABLE teaching_assignment
# 2026-04-10 22:01:32,010 INFO sqlalchemy.engine.Engine [no key 0.00899s] {}
# 2026-04-10 22:01:32,279 INFO sqlalchemy.engine.Engine
# DROP TABLE learning_result
# 2026-04-10 22:01:32,283 INFO sqlalchemy.engine.Engine [no key 0.00370s] {}
# 2026-04-10 22:01:32,480 INFO sqlalchemy.engine.Engine
# DROP TABLE class_room
# 2026-04-10 22:01:32,482 INFO sqlalchemy.engine.Engine [no key 0.00152s] {}
# 2026-04-10 22:01:32,659 INFO sqlalchemy.engine.Engine
# DROP TABLE teacher
# 2026-04-10 22:01:32,661 INFO sqlalchemy.engine.Engine [no key 0.00157s] {}
# 2026-04-10 22:01:32,841 INFO sqlalchemy.engine.Engine
# DROP TABLE subject
# 2026-04-10 22:01:32,844 INFO sqlalchemy.engine.Engine [no key 0.00352s] {}
# 2026-04-10 22:01:33,023 INFO sqlalchemy.engine.Engine
# DROP TABLE student
# 2026-04-10 22:01:33,024 INFO sqlalchemy.engine.Engine [no key 0.00127s] {}
# 2026-04-10 22:01:33,208 INFO sqlalchemy.engine.Engine
# DROP TABLE semester
# 2026-04-10 22:01:33,212 INFO sqlalchemy.engine.Engine [no key 0.00414s] {}
# 2026-04-10 22:01:33,390 INFO sqlalchemy.engine.Engine
# DROP TABLE score
# 2026-04-10 22:01:33,394 INFO sqlalchemy.engine.Engine [no key 0.00338s] {}
# 2026-04-10 22:01:33,571 INFO sqlalchemy.engine.Engine
# DROP TABLE grade_level
# 2026-04-10 22:01:33,573 INFO sqlalchemy.engine.Engine [no key 0.00129s] {}
# 2026-04-10 22:01:33,756 INFO sqlalchemy.engine.Engine
# DROP TABLE academic_year
# 2026-04-10 22:01:33,759 INFO sqlalchemy.engine.Engine [no key 0.00294s] {}
# 2026-04-10 22:01:33,940 INFO sqlalchemy.engine.Engine COMMIT
# All tables dropped
# 2026-04-10 22:01:34,242 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 22:01:34,244 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:34,246 INFO sqlalchemy.engine.Engine [cached since 4.319s ago] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:34,616 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:34,617 INFO sqlalchemy.engine.Engine [cached since 4.691s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:34,806 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:34,810 INFO sqlalchemy.engine.Engine [cached since 4.883s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:35,007 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:35,009 INFO sqlalchemy.engine.Engine [cached since 5.082s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:35,189 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:35,192 INFO sqlalchemy.engine.Engine [cached since 5.265s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:35,379 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:35,380 INFO sqlalchemy.engine.Engine [cached since 5.453s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:35,560 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:35,562 INFO sqlalchemy.engine.Engine [cached since 5.635s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:35,744 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:35,748 INFO sqlalchemy.engine.Engine [cached since 5.821s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:35,943 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:35,946 INFO sqlalchemy.engine.Engine [cached since 6.019s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:36,127 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-10 22:01:36,130 INFO sqlalchemy.engine.Engine [cached since 6.203s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-10 22:01:36,311 INFO sqlalchemy.engine.Engine
# CREATE TABLE academic_year (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:36,314 INFO sqlalchemy.engine.Engine [no key 0.00250s] {}
# 2026-04-10 22:01:36,538 INFO sqlalchemy.engine.Engine
# CREATE TABLE grade_level (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	max_students INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:36,544 INFO sqlalchemy.engine.Engine [no key 0.00583s] {}
# 2026-04-10 22:01:36,734 INFO sqlalchemy.engine.Engine
# CREATE TABLE score (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:36,739 INFO sqlalchemy.engine.Engine [no key 0.00459s] {}
# 2026-04-10 22:01:36,925 INFO sqlalchemy.engine.Engine
# CREATE TABLE semester (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(20) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:36,928 INFO sqlalchemy.engine.Engine [no key 0.00271s] {}
# 2026-04-10 22:01:37,125 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	address TEXT,
# 	place_of_birth TEXT,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:37,128 INFO sqlalchemy.engine.Engine [no key 0.00337s] {}
# 2026-04-10 22:01:37,313 INFO sqlalchemy.engine.Engine
# CREATE TABLE subject (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	total_periods INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:37,320 INFO sqlalchemy.engine.Engine [no key 0.00726s] {}
# 2026-04-10 22:01:37,507 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	specialization VARCHAR(50),
# 	position VARCHAR(50),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-10 22:01:37,513 INFO sqlalchemy.engine.Engine [no key 0.00559s] {}
# 2026-04-10 22:01:37,709 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_room (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	size INTEGER NOT NULL,
# 	special_program VARCHAR(50),
# 	grade_level_code VARCHAR(20) NOT NULL,
# 	PRIMARY KEY (code),
# 	FOREIGN KEY(grade_level_code) REFERENCES grade_level (code)
# )
#
#
# 2026-04-10 22:01:37,712 INFO sqlalchemy.engine.Engine [no key 0.00312s] {}
# 2026-04-10 22:01:37,913 INFO sqlalchemy.engine.Engine
# CREATE TABLE learning_result (
# 	student_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	academic_year_code VARCHAR(20) NOT NULL,
# 	semester_code VARCHAR(20) NOT NULL,
# 	score_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	enrollment_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_code, class_code, academic_year_code, semester_code, score_code, subject_code),
# 	FOREIGN KEY(student_code) REFERENCES student (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_code) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_code) REFERENCES semester (code),
# 	FOREIGN KEY(score_code) REFERENCES score (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-10 22:01:37,917 INFO sqlalchemy.engine.Engine [no key 0.00356s] {}
# 2026-04-10 22:01:38,108 INFO sqlalchemy.engine.Engine
# CREATE TABLE teaching_assignment (
# 	teacher_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	role VARCHAR(30) NOT NULL,
# 	periods_per_week INTEGER NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (teacher_code, class_code, subject_code),
# 	FOREIGN KEY(teacher_code) REFERENCES teacher (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-10 22:01:38,110 INFO sqlalchemy.engine.Engine [no key 0.00208s] {}
# 2026-04-10 22:01:38,296 INFO sqlalchemy.engine.Engine COMMIT
# 2026-04-10 22:01:38,481 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 22:01:38,487 INFO sqlalchemy.engine.Engine ALTER TABLE academic_year ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:38,492 INFO sqlalchemy.engine.Engine [generated in 0.01090s] {}
# 2026-04-10 22:01:38,873 INFO sqlalchemy.engine.Engine ALTER TABLE learning_result ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:38,876 INFO sqlalchemy.engine.Engine [generated in 0.00511s] {}
# 2026-04-10 22:01:39,060 INFO sqlalchemy.engine.Engine ALTER TABLE class_room ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:39,063 INFO sqlalchemy.engine.Engine [generated in 0.00278s] {}
# 2026-04-10 22:01:39,244 INFO sqlalchemy.engine.Engine ALTER TABLE grade_level ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:39,246 INFO sqlalchemy.engine.Engine [generated in 0.00197s] {}
# 2026-04-10 22:01:39,425 INFO sqlalchemy.engine.Engine ALTER TABLE score ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:39,430 INFO sqlalchemy.engine.Engine [generated in 0.00464s] {}
# 2026-04-10 22:01:39,614 INFO sqlalchemy.engine.Engine ALTER TABLE semester ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:39,617 INFO sqlalchemy.engine.Engine [generated in 0.00311s] {}
# 2026-04-10 22:01:39,814 INFO sqlalchemy.engine.Engine ALTER TABLE student ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:39,816 INFO sqlalchemy.engine.Engine [generated in 0.00241s] {}
# 2026-04-10 22:01:40,010 INFO sqlalchemy.engine.Engine ALTER TABLE subject ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:40,012 INFO sqlalchemy.engine.Engine [generated in 0.00221s] {}
# 2026-04-10 22:01:40,189 INFO sqlalchemy.engine.Engine ALTER TABLE teacher ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:40,192 INFO sqlalchemy.engine.Engine [generated in 0.00297s] {}
# 2026-04-10 22:01:40,374 INFO sqlalchemy.engine.Engine ALTER TABLE teaching_assignment ENABLE ROW LEVEL SECURITY;
# 2026-04-10 22:01:40,378 INFO sqlalchemy.engine.Engine [generated in 0.00414s] {}
# 2026-04-10 22:01:40,571 INFO sqlalchemy.engine.Engine COMMIT
# Tables created + RLS enabled
# Tables created
