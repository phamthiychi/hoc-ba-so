# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager
from src.adapter.database.mongo_manager import mongo_manager
from src.adapter.graph.neo4j_manager import neo4j_manager

postgres_manager.delete_db()
postgres_manager.create_db()

mongo_manager.clean_metadata_db("contact_infos")
mongo_manager.clean_metadata_db("subject_assessments")

neo4j_manager.clean_database()
# Out:
# 2026-04-05 22:18:20,354 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-04-05 22:18:20,355 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-05 22:18:20,605 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-04-05 22:18:20,606 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-05 22:18:20,856 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-04-05 22:18:20,857 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-05 22:18:21,106 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-05 22:18:21,112 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,112 INFO sqlalchemy.engine.Engine [generated in 0.00061s] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:21,363 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,364 INFO sqlalchemy.engine.Engine [cached since 0.2523s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:21,490 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,491 INFO sqlalchemy.engine.Engine [cached since 0.3794s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:21,617 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,619 INFO sqlalchemy.engine.Engine [cached since 0.5074s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:21,745 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,746 INFO sqlalchemy.engine.Engine [cached since 0.6347s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:21,872 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,873 INFO sqlalchemy.engine.Engine [cached since 0.7612s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:21,998 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:21,999 INFO sqlalchemy.engine.Engine [cached since 0.8879s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:22,126 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:22,127 INFO sqlalchemy.engine.Engine [cached since 1.016s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:22,253 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:22,255 INFO sqlalchemy.engine.Engine [cached since 1.143s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:22,380 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:22,381 INFO sqlalchemy.engine.Engine [cached since 1.269s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:22,506 INFO sqlalchemy.engine.Engine
# DROP TABLE teaching_assignment
# 2026-04-05 22:18:22,507 INFO sqlalchemy.engine.Engine [no key 0.00132s] {}
# 2026-04-05 22:18:22,644 INFO sqlalchemy.engine.Engine
# DROP TABLE learning_result
# 2026-04-05 22:18:22,645 INFO sqlalchemy.engine.Engine [no key 0.00141s] {}
# 2026-04-05 22:18:22,774 INFO sqlalchemy.engine.Engine
# DROP TABLE class_room
# 2026-04-05 22:18:22,775 INFO sqlalchemy.engine.Engine [no key 0.00134s] {}
# 2026-04-05 22:18:22,901 INFO sqlalchemy.engine.Engine
# DROP TABLE teacher
# 2026-04-05 22:18:22,901 INFO sqlalchemy.engine.Engine [no key 0.00078s] {}
# 2026-04-05 22:18:23,027 INFO sqlalchemy.engine.Engine
# DROP TABLE subject
# 2026-04-05 22:18:23,028 INFO sqlalchemy.engine.Engine [no key 0.00124s] {}
# 2026-04-05 22:18:23,154 INFO sqlalchemy.engine.Engine
# DROP TABLE student
# 2026-04-05 22:18:23,155 INFO sqlalchemy.engine.Engine [no key 0.00130s] {}
# 2026-04-05 22:18:23,282 INFO sqlalchemy.engine.Engine
# DROP TABLE semester
# 2026-04-05 22:18:23,283 INFO sqlalchemy.engine.Engine [no key 0.00142s] {}
# 2026-04-05 22:18:23,409 INFO sqlalchemy.engine.Engine
# DROP TABLE score
# 2026-04-05 22:18:23,410 INFO sqlalchemy.engine.Engine [no key 0.00103s] {}
# 2026-04-05 22:18:23,535 INFO sqlalchemy.engine.Engine
# DROP TABLE grade_level
# 2026-04-05 22:18:23,537 INFO sqlalchemy.engine.Engine [no key 0.00132s] {}
# 2026-04-05 22:18:23,663 INFO sqlalchemy.engine.Engine
# DROP TABLE academic_year
# 2026-04-05 22:18:23,664 INFO sqlalchemy.engine.Engine [no key 0.00131s] {}
# 2026-04-05 22:18:23,790 INFO sqlalchemy.engine.Engine COMMIT
# All tables dropped
# 2026-04-05 22:18:23,919 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-05 22:18:23,919 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:23,919 INFO sqlalchemy.engine.Engine [cached since 2.808s ago] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,168 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,169 INFO sqlalchemy.engine.Engine [cached since 3.058s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,296 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,298 INFO sqlalchemy.engine.Engine [cached since 3.186s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,424 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,425 INFO sqlalchemy.engine.Engine [cached since 3.313s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,550 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,552 INFO sqlalchemy.engine.Engine [cached since 3.44s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,677 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,679 INFO sqlalchemy.engine.Engine [cached since 3.567s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,805 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,806 INFO sqlalchemy.engine.Engine [cached since 3.695s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:24,932 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:24,933 INFO sqlalchemy.engine.Engine [cached since 3.821s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:25,058 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:25,059 INFO sqlalchemy.engine.Engine [cached since 3.948s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:25,185 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-04-05 22:18:25,186 INFO sqlalchemy.engine.Engine [cached since 4.075s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-04-05 22:18:25,314 INFO sqlalchemy.engine.Engine
# CREATE TABLE academic_year (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:25,315 INFO sqlalchemy.engine.Engine [no key 0.00130s] {}
# 2026-04-05 22:18:25,444 INFO sqlalchemy.engine.Engine
# CREATE TABLE grade_level (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	max_students INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:25,445 INFO sqlalchemy.engine.Engine [no key 0.00122s] {}
# 2026-04-05 22:18:25,572 INFO sqlalchemy.engine.Engine
# CREATE TABLE score (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:25,573 INFO sqlalchemy.engine.Engine [no key 0.00132s] {}
# 2026-04-05 22:18:25,700 INFO sqlalchemy.engine.Engine
# CREATE TABLE semester (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(20) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:25,702 INFO sqlalchemy.engine.Engine [no key 0.00176s] {}
# 2026-04-05 22:18:25,828 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	address TEXT,
# 	place_of_birth TEXT,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:25,829 INFO sqlalchemy.engine.Engine [no key 0.00068s] {}
# 2026-04-05 22:18:25,956 INFO sqlalchemy.engine.Engine
# CREATE TABLE subject (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	total_periods INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:25,957 INFO sqlalchemy.engine.Engine [no key 0.00129s] {}
# 2026-04-05 22:18:26,084 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	specialization VARCHAR(50),
# 	position VARCHAR(50),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-04-05 22:18:26,086 INFO sqlalchemy.engine.Engine [no key 0.00146s] {}
# 2026-04-05 22:18:26,213 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_room (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	size INTEGER NOT NULL,
# 	special_program VARCHAR(50),
# 	grade_level_code VARCHAR(20) NOT NULL,
# 	PRIMARY KEY (code),
# 	FOREIGN KEY(grade_level_code) REFERENCES grade_level (code)
# )
#
#
# 2026-04-05 22:18:26,214 INFO sqlalchemy.engine.Engine [no key 0.00130s] {}
# 2026-04-05 22:18:26,341 INFO sqlalchemy.engine.Engine
# CREATE TABLE learning_result (
# 	student_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	academic_year_code VARCHAR(20) NOT NULL,
# 	semester_code VARCHAR(20) NOT NULL,
# 	score_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	enrollment_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_code, class_code, academic_year_code, semester_code, score_code, subject_code),
# 	FOREIGN KEY(student_code) REFERENCES student (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_code) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_code) REFERENCES semester (code),
# 	FOREIGN KEY(score_code) REFERENCES score (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-05 22:18:26,341 INFO sqlalchemy.engine.Engine [no key 0.00064s] {}
# 2026-04-05 22:18:26,470 INFO sqlalchemy.engine.Engine
# CREATE TABLE teaching_assignment (
# 	teacher_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	role VARCHAR(30) NOT NULL,
# 	periods_per_week INTEGER NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (teacher_code, class_code, subject_code),
# 	FOREIGN KEY(teacher_code) REFERENCES teacher (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-04-05 22:18:26,471 INFO sqlalchemy.engine.Engine [no key 0.00100s] {}
# 2026-04-05 22:18:26,598 INFO sqlalchemy.engine.Engine COMMIT
# 2026-04-05 22:18:26,725 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-05 22:18:26,727 INFO sqlalchemy.engine.Engine ALTER TABLE academic_year ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:26,728 INFO sqlalchemy.engine.Engine [generated in 0.00253s] {}
# 2026-04-05 22:18:26,978 INFO sqlalchemy.engine.Engine ALTER TABLE learning_result ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:26,979 INFO sqlalchemy.engine.Engine [generated in 0.00090s] {}
# 2026-04-05 22:18:27,105 INFO sqlalchemy.engine.Engine ALTER TABLE class_room ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,106 INFO sqlalchemy.engine.Engine [generated in 0.00128s] {}
# 2026-04-05 22:18:27,231 INFO sqlalchemy.engine.Engine ALTER TABLE grade_level ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,233 INFO sqlalchemy.engine.Engine [generated in 0.00136s] {}
# 2026-04-05 22:18:27,359 INFO sqlalchemy.engine.Engine ALTER TABLE score ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,360 INFO sqlalchemy.engine.Engine [generated in 0.00133s] {}
# 2026-04-05 22:18:27,485 INFO sqlalchemy.engine.Engine ALTER TABLE semester ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,486 INFO sqlalchemy.engine.Engine [generated in 0.00116s] {}
# 2026-04-05 22:18:27,611 INFO sqlalchemy.engine.Engine ALTER TABLE student ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,613 INFO sqlalchemy.engine.Engine [generated in 0.00137s] {}
# 2026-04-05 22:18:27,739 INFO sqlalchemy.engine.Engine ALTER TABLE subject ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,740 INFO sqlalchemy.engine.Engine [generated in 0.00122s] {}
# 2026-04-05 22:18:27,865 INFO sqlalchemy.engine.Engine ALTER TABLE teacher ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,866 INFO sqlalchemy.engine.Engine [generated in 0.00108s] {}
# 2026-04-05 22:18:27,992 INFO sqlalchemy.engine.Engine ALTER TABLE teaching_assignment ENABLE ROW LEVEL SECURITY;
# 2026-04-05 22:18:27,994 INFO sqlalchemy.engine.Engine [generated in 0.00126s] {}
# 2026-04-05 22:18:28,118 INFO sqlalchemy.engine.Engine COMMIT
# Tables created + RLS enabled
# Tables created
