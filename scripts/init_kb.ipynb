# %%
import sys
import os
import shutil

sys.path.append(os.path.abspath(".."))

from src.adapter.graph.knowledge_base import KnowledgeBase
from src.application.embedding import EmbeddingSentence

student_assessment_kb = KnowledgeBase().student_assessments.define
embedding_assessment = EmbeddingSentence()

folder = "../cache"

for filename in os.listdir(folder):
    file_path = os.path.join(folder, filename)
    if os.path.isfile(file_path):
        os.remove(file_path)
    else:
        shutil.rmtree(file_path)

embedding_assessment.emb_knowledge(knowledge_base=student_assessment_kb["Phẩm chất"], name="quality")
embedding_assessment.emb_knowledge(knowledge_base=student_assessment_kb["Năng lực chung"], name="general")
embedding_assessment.emb_knowledge(knowledge_base={"vietnamese": student_assessment_kb["Môn học"]["Tiếng Việt"]}, name="vietnamese")
embedding_assessment.emb_knowledge(knowledge_base={"mathematics":student_assessment_kb["Môn học"]["Toán"]}, name="mathematics")
embedding_assessment.emb_knowledge(knowledge_base={"informatics":student_assessment_kb["Môn học"]["Tin học"]}, name="informatics")
embedding_assessment.emb_knowledge(knowledge_base={"science":student_assessment_kb["Môn học"]["Khoa học"]}, name="science")
embedding_assessment.emb_knowledge(knowledge_base={"history_and_geography":student_assessment_kb["Môn học"]["Lịch sử và Địa lý"]}, name="history_and_geography")
embedding_assessment.emb_knowledge(knowledge_base={"english":student_assessment_kb["Môn học"]["Tiếng Anh"]}, name="english")
embedding_assessment.emb_knowledge(knowledge_base={"technology":student_assessment_kb["Môn học"]["Công nghệ"]}, name="technology")
embedding_assessment.emb_knowledge(knowledge_base={"music":student_assessment_kb["Môn học"]["Âm nhạc"]}, name="music")
embedding_assessment.emb_knowledge(knowledge_base={"arts":student_assessment_kb["Môn học"]["Mĩ thuật"]}, name="arts")
embedding_assessment.emb_knowledge(knowledge_base={"civics":student_assessment_kb["Môn học"]["Giáo dục công dân"]}, name="civics")
embedding_assessment.emb_knowledge(knowledge_base={"physical_education":student_assessment_kb["Môn học"]["Giáo dục thể chất"]}, name="physical_education")
embedding_assessment.emb_knowledge(knowledge_base={"experiential_activities":student_assessment_kb["Môn học"]["Hoạt động trải nghiệm"]}, name="experiential_activities")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 3154.12it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...
# Batches: 100%|██████████| 9/9 [00:01<00:00,  4.60it/s]
# {'encode': tensor([[-0.0423, -0.0350,  0.0377,  ...,  0.3764, -0.5374, -0.1320],
#          [ 0.1322, -0.0895, -0.0628,  ...,  0.2172, -0.0130,  0.1392],
#          [ 0.0478, -0.0431, -0.0404,  ...,  0.1699, -0.0713,  0.0082],
#          ...,
#          [ 0.1248,  0.1784, -0.2651,  ...,  0.1814, -0.2321, -0.0788],
#          [ 0.1860,  0.2277, -0.4171,  ..., -0.0994, -0.0165,  0.0738],
#          [ 0.1637,  0.2300, -0.2567,  ...,  0.0091, -0.1083, -0.0609]]),
# ...
